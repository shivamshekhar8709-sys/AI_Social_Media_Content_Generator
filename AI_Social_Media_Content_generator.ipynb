# %% [markdown]
# # 🚀 AI Social Media Content Generator using Google Gemini
#
# Welcome to this hands-on masterclass!
#
# In this notebook, we will build an AI-powered Social Media Content Generator using Google Gemini API.
#
# By the end of this session, you'll be able to generate:
# - ✨ LinkedIn Posts
# - 📸 Instagram Captions
# - 🏷️ Trending Hashtags
# - 📅 Weekly Content Calendars
# - 📢 Call-to-Action Statements
#
# We'll also learn:
# - ✅ Generative AI
# - ✅ Prompt Engineering
# - ✅ Google Gemini API
# - ✅ Python Integration
# - ✅ Building Real-World AI Applications

# %% [markdown]
#            AI Social Media Content Generator
#
#          👤 User Input
#                 │
#                 ▼
#       🧠 Prompt Engineering
#                 │
#                 ▼
#         🤖 Google Gemini
#                 │
#       ┌─────────┴─────────┐
#       ▼         ▼         ▼
#   📝 Content  🏷️ Tags  📣 CTA
#                 │
#                 ▼
#       🎨 AI Image Prompt
#                 │
#                 ▼
#          🖼️ Final Creative

# %% [markdown]
# ## Step 1: Install Google Gemini SDK
#
# First, we'll install the Google Gemini SDK.
#
# This library enables our Python program to communicate with Google's Gemini AI models.

# %%
# Install Google Gemini SDK

# !pip install -q google-genai

# %% [markdown]
# ## Step 2: Connect to Google Gemini
#
# To access Gemini models, we need to authenticate using an API key.
#
# Think of the API key as a secure password that allows our application to communicate with Google's AI services.

# %%
from google import genai

# Read the API key from the text file (corrected filename)
with open('gemini api key.txt', 'r') as f:
    api_key = f.read().strip()

client = genai.Client(
    api_key=api_key
)

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
models = client.models.list()

for model in models:
    print(model.name)
    break
# Out:
# models/gemini-2.5-flash

# %% [markdown]
# ## Step 3: Collect User Inputs
#
# Now we'll collect the details from the user.
#
# These inputs will help our AI generate personalized social media content based on:
# - Topic
# - Platform
# - Tone
# - Target Audience
# - Content Type

# %%
topic = input("Enter the topic: ")

platform = input("Choose platform (LinkedIn/Instagram/X): ")

tone = input("Choose tone (Professional/Friendly/Funny): ")

audience = input("Target audience: ")

content_type = input("Content type (Post/Caption/Carousel): ")
# Out:
# Enter the topic: Quantum Computing: Our Future
# Choose platform (LinkedIn/Instagram/X): LinkedIn
# Choose tone (Professional/Friendly/Funny): Professional
# Target audience: Tech students
# Content type (Post/Caption/Carousel): Post.

# %% [markdown]
# ## Step 4: Create the AI Prompt
#
# This is the most important step.
#
# Here, we'll combine all the user inputs into a well-structured prompt.
#
# The better the prompt, the better the AI-generated content.

# %%
prompt = f"""
You are an expert Social Media Content Creator.

Generate high-quality content based on the following details.

Topic: {topic}
Platform: {platform}
Tone: {tone}
Target Audience: {audience}
Content Type: {content_type}

Return the output in the following format only:

## 📢 Social Media Post
(Write one engaging post)

## 🏷️ Hashtags
(Generate exactly 5 trending hashtags)

## 📣 Call-To-Action
(Write one engaging CTA)

## 💡 Next Content Idea
(Suggest one related content idea)

Keep the language engaging, concise, and platform-specific.
"""

# %% [markdown]
# ## Step 5: Generate Content using Google Gemini
#
# Now that our prompt is ready, we'll send it to the Gemini AI model.
#
# The model will understand our instructions and generate high-quality social media content based on the user's inputs.

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

# %% [markdown]
# ## Step 6: Display the Generated Content
#
# Let's display the AI-generated social media content.

# %%
print(response.text)
# Out:
# ## 📢 Social Media Post
#
# Classical computing built the modern world. Quantum computing is about to reinvent it. 🚀
#
# If you’re a computer science or engineering student today, you are standing at the edge of a massive paradigm shift. We are moving from the predictable world of binary bits (0s and 1s) to the exponential potential of **qubits**—leveraging superposition and entanglement to solve problems that would take classical supercomputers millennia to crunch.
#
# Why should this matter to your future tech career?
#
# 🔹 **Redefining Complex Fields:** From breaking modern encryption to simulating complex molecular structures for breakthrough drug discovery, quantum logic changes *how* we solve intractable problems.
# 🔹 **The Rise of Deep Tech:** Major tech giants and innovative startups are heavily investing in quantum infrastructure. The demand for quantum-aware engineers is rising faster than the supply.
# 🔹 **Accessible Right Now:** You don't need a PhD in theoretical physics to start. Frameworks like IBM’s Qiskit, Google’s Cirq, and Xanadu’s PennyLane allow you to write and run quantum code on real hardware directly from your laptop.
#
# The best time to learn a foundational technology is *before* it becomes mainstream. Understanding quantum concepts today could be the single biggest differentiator for your career tomorrow.
#
# Are you building for the current wave of tech, or the next one?
#
# ---
#
# ## 🏷️ Hashtags
# #QuantumComputing #TechCareers #FutureOfTech #SoftwareEngineering #DeepTech
#
# ## 📣 Call-To-Action
# Which open-source quantum framework are you most curious to explore first? Drop your thoughts or questions in the comments below!
#
# ## 💡 Next Content Idea
# A beginner-friendly carousel titled: **"Classical vs. Quantum Logic: How to Write Your First 'Hello World' Quantum Circuit."**

# %% [markdown]
# ## Step 7: Improve the Content
#
# One of the biggest advantages of Generative AI is that we don't have to start from scratch.
#
# We can ask the AI to improve, rewrite, shorten, or change the tone of previously generated content simply by giving it another prompt.

# %%
improvement_prompt = f"""
Rewrite the following social media content.

Content:

{response.text}

Make it:

- More engaging
- More professional
- More concise
- Add relevant emojis
- Keep it suitable for {platform}
"""

improved_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=improvement_prompt
)

print(improved_response.text)
# Out:
# Here's a rewritten version of your social media content, optimized for LinkedIn:
#
# ---
#
# ## 📢 Social Media Post
#
# The world you know, built by classical computing, is on the brink of a quantum revolution. 🚀 For computer science and engineering students, this isn't just a trend—it's the next frontier.
#
# You're at the cusp of a profound paradigm shift: from the predictable world of binary bits (0s & 1s) to the exponential power of **qubits**. Leveraging superposition and entanglement, quantum computers are poised to tackle problems that would take classical supercomputers millennia.
#
# **Why should this define your future tech career?**
#
# *   ✨ **Solve the Unsolvable:** Quantum logic redefines *how* we approach intractable challenges—from cracking modern encryption to simulating complex molecular structures for breakthrough drug discovery. Imagine the impact!
# *   📈 **Exploding Demand in Deep Tech:** Major tech giants and innovative startups are investing heavily in quantum infrastructure. The demand for quantum-aware engineers is skyrocketing, creating a massive talent gap.
# *   💻 **Hands-On & Accessible:** No PhD required to begin! Dive in with frameworks like IBM Qiskit, Google Cirq, or Xanadu PennyLane to write and run quantum code on real hardware directly from your laptop. The future is here, now.
#
# Mastering foundational quantum concepts *before* they're mainstream will be your career's ultimate differentiator. Are you ready to build for the next wave of innovation? 🌊
#
# ---
#
# ## 🏷️ Hashtags
# #QuantumComputing #TechCareers #FutureOfTech #SoftwareEngineering #DeepTech #Innovation
#
# ## 📣 Call-To-Action
# Which open-source quantum framework excites you most? Share your thoughts or questions in the comments! 👇
#
# ## 💡 Next Content Idea
# A beginner-friendly carousel titled: **"Classical vs. Quantum Logic: How to Write Your First 'Hello World' Quantum Circuit."**

# %% [markdown]
# ## Step 9: Generate an AI Image Prompt
#
# Great content deserves great visuals!
#
# Let's ask AI to generate a professional image prompt that can be used in AI image generation tools to create social media graphics.

# %%
image_prompt = f"""
You are an expert AI Image Prompt Engineer.

Generate one highly detailed image prompt for the following topic.

Topic: {topic}

Target Audience: {audience}

The image should look professional, modern, attractive, and suitable for posting on {platform}.

Only generate the image prompt.
"""

image_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=image_prompt
)

print(image_response.text)
# Out:
# A highly detailed, professional, and modern conceptual digital illustration representing "Quantum Computing: Our Future." The central focus is a stunning array of intricately interconnected quantum bits (qubits), depicted as glowing, iridescent spheres or crystalline nodes, suspended within a sleek, futuristic abstract quantum processor architecture. Delicate energy streams and light trails visually represent superposition and entanglement, weaving between the qubits in a dynamic, ethereal dance. The surrounding environment subtly fades into a background of abstract, interconnected data networks and global light patterns, symbolizing the technology's widespread future impact and applications.
#
# The color palette is dominated by deep blues, vibrant purples, and electric cyans, accented with luminous electric green, magenta, and polished silver or chrome highlights. Dramatic, volumetric lighting creates a sense of depth and wonder, with brilliant focal glows emanating from the qubits and circuitry, contrasting against a sophisticated dark background. The overall aesthetic is clean, cutting-edge, inspiring, and intelligent, designed with a hyper-realistic digital art style, crisp details, sharp focus, and a polished finish suitable for a professional LinkedIn post. Aspect ratio 16:9. Conceptual art, sci-fi illustration, generative art, 8k, ultra detailed, vibrant, luminous, professional.

# %%
from PIL import Image

# Updated the filename to match the actual file in /content/sample_data/
image = Image.open("/content/sample_data/Generated image 1 (2).png")

# %% [markdown]
# ## Step 12: Analyze the Generated Image using Gemini
#
# Generative AI is not limited to text generation.
#
# Gemini is a multimodal AI model, which means it can understand both text and images.
#
# Let's upload our generated image and ask Gemini to analyze whether it matches the social media content we created.

# %%
analysis_prompt = f"""
You are an expert social media marketing consultant.

Analyze this image based on the following details.

Topic: {topic}

Platform: {platform}

Target Audience: {audience}

Please answer:

1. Does this image match the topic?
2. Is it suitable for {platform}?
3. What emotions does it convey?
4. What could be improved?
5. Give the image a rating out of 10.
"""

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=[
        analysis_prompt,
        image
    ]
)

print(response.text)
# Out:
# Here is a professional social media marketing analysis of the image based on your parameters:
#
# ---
#
# ### **1. Does this image match the topic?**
# **Yes, exceptionally well.**
# * **Direct Relevance:** It explicitly features a "Quantum Processor" at the center, surrounded by glowing quantum state orbits, light rays, and technical overlays.
# * **Accuracy & Context:** Unlike generic tech stock photos with random numbers, this graphic actually incorporates accurate quantum mechanics concepts—such as the mathematical superposition equation $\frac{|0\rangle + |1\rangle}{\sqrt{2}}$, quantum gate/circuit diagrams, and fundamental principles (Superposition, Entanglement, Interference, Measurement).
# * **Future-Oriented:** The tagline *"Beyond Bits. Into Possibilities"* and the application list (AI, Drug Discovery, Climate Simulation) perfectly align with the "Our Future" narrative.
#
# ---
#
# ### **2. Is it suitable for LinkedIn?**
# **Yes, highly suitable.**
# * **Professional & Polished:** The high-definition, glowing sci-fi aesthetic stands out in the standard corporate LinkedIn feed, acting as a strong "scroll-stopper."
# * **Educational Value:** LinkedIn audiences (especially students and industry professionals) value informative content. The infographic-style elements (application list, core pillars at the bottom) elevate it from mere visual art to an educational asset.
# * **Target Audience Fit:** Tech students respond well to visually dynamic, modern imagery that makes complex subjects feel exciting, cutting-edge, and accessible.
#
# ---
#
# ### **3. What emotions does it convey?**
# * **Awe & Wonder:** The glowing neon aesthetics, floating processor, and cosmic quantum particles evoke a sense of futuristic wonder.
# * **Empowerment & Control:** The human hand reaching upward suggests that humanity is shaping and holding the power of this technology, inviting students to be part of building it.
# * **Inspiration & Ambition:** Text like *"Beyond Bits. Into Possibilities"* triggers curiosity and career ambition for students deciding on their specialization.
# * **Intellectual Engagement:** The equations and technical diagrams stimulate curiosity and respect among technical minds.
#
# ---
#
# ### **4. What could be improved?**
#
# 1. **Mobile Text Legibility:**
#    * The text in the side boxes (*Qubit State*, *Quantum Algorithm*, *Potential applications*) is quite small. On a mobile phone screen, LinkedIn users may struggle to read those detailed points without zooming in. Increasing the font size slightly or simplifying side text would improve mobile UX.
# 2. **Branding / Call to Action (CTA):**
#    * If this post is meant to drive traffic (e.g., to an article, university course, or event), adding a subtle logo or a prompt like *"Swipe to explore the future"* or a brand handle would increase conversion rates.
# 3. **Visual Density / Cognitive Load:**
#    * There is a lot happening visually simultaneously (atomic rings, background server racks, floating text boxes, hand light, bottom bar). Slightly reducing background clutter could make the central message pop even more.
#
# ---
#
# ### **5. Rating: 9 / 10**
#
# **Summary:** This is a top-tier creative asset for LinkedIn targeting tech students. It perfectly balances high aesthetic appeal with technical credibility, making quantum computing look exciting, prestigious, and full of potential. A minor tweak to mobile text legibility would make it a 10/10.

# %%
from IPython.display import Markdown, display

display(Markdown(improved_response.text))
display(image)
# Out:
# Here's a rewritten version of your social media content, optimized for LinkedIn:
#
# ---
#
# ## 📢 Social Media Post
#
# The world you know, built by classical computing, is on the brink of a quantum revolution. 🚀 For computer science and engineering students, this isn't just a trend—it's the next frontier.
#
# You're at the cusp of a profound paradigm shift: from the predictable world of binary bits (0s & 1s) to the exponential power of **qubits**. Leveraging superposition and entanglement, quantum computers are poised to tackle problems that would take classical supercomputers millennia.
#
# **Why should this define your future tech career?**
#
# *   ✨ **Solve the Unsolvable:** Quantum logic redefines *how* we approach intractable challenges—from cracking modern encryption to simulating complex molecular structures for breakthrough drug discovery. Imagine the impact!
# *   📈 **Exploding Demand in Deep Tech:** Major tech giants and innovative startups are investing heavily in quantum infrastructure. The demand for quantum-aware engineers is skyrocketing, creating a massive talent gap.
# *   💻 **Hands-On & Accessible:** No PhD required to begin! Dive in with frameworks like IBM Qiskit, Google Cirq, or Xanadu PennyLane to write and run quantum code on real hardware directly from your laptop. The future is here, now.
#
# Mastering foundational quantum concepts *before* they're mainstream will be your career's ultimate differentiator. Are you ready to build for the next wave of innovation? 🌊
#
# ---
#
# ## 🏷️ Hashtags
# #QuantumComputing #TechCareers #FutureOfTech #SoftwareEngineering #DeepTech #Innovation
#
# ## 📣 Call-To-Action
# Which open-source quantum framework excites you most? Share your thoughts or questions in the comments! 👇
#
# ## 💡 Next Content Idea
# A beginner-friendly carousel titled: **"Classical vs. Quantum Logic: How to Write Your First 'Hello World' Quantum Circuit."**
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1122x1402>
