# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamshekhar8709-sys/AI_Social_Media_Content_Generator/blob/main/AI_Social_Media_Content_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 AI Social Media Content Generator using Google Gemini
#
# Welcome to this hands-on masterclass!
#
# In this notebook, we will build an AI-powered Social Media Content Generator using Google Gemini API.
#
# By the end of this session, you'll be able to generate:
# - ✨ LinkedIn Posts
# - 📸 Instagram Captions
# - 🏷️ Trending Hashtags
# - 📅 Weekly Content Calendars
# - 📢 Call-to-Action Statements
#
# We'll also learn:
# - ✅ Generative AI
# - ✅ Prompt Engineering
# - ✅ Google Gemini API
# - ✅ Python Integration
# - ✅ Building Real-World AI Applications

# %% [markdown]
#            AI Social Media Content Generator
#
#          👤 User Input
#                 │
#                 ▼
#       🧠 Prompt Engineering
#                 │
#                 ▼
#         🤖 Google Gemini
#                 │
#       ┌─────────┴─────────┐
#       ▼         ▼         ▼
#   📝 Content  🏷️ Tags  📣 CTA
#                 │
#                 ▼
#       🎨 AI Image Prompt
#                 │
#                 ▼
#          🖼️ Final Creative

# %% [markdown]
# ## Step 1: Install Google Gemini SDK
#
# First, we'll install the Google Gemini SDK.
#
# This library enables our Python program to communicate with Google's Gemini AI models.

# %%
# Install Google Gemini SDK

# !pip install -q google-genai

# %% [markdown]
# ## Step 2: Connect to Google Gemini
#
# To access Gemini models, we need to authenticate using an API key.
#
# Think of the API key as a secure password that allows our application to communicate with Google's AI services.

# %%
from google import genai

# Read the API key from the text file (corrected filename)
with open('gemini api key.txt', 'r') as f:
    api_key = f.read().strip()

client = genai.Client(
    api_key=api_key
)

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
models = client.models.list()

for model in models:
    print(model.name)
    break
# Out:
# models/gemini-2.5-flash

# %% [markdown]
# ## Step 3: Collect User Inputs
#
# Now we'll collect the details from the user.
#
# These inputs will help our AI generate personalized social media content based on:
# - Topic
# - Platform
# - Tone
# - Target Audience
# - Content Type

# %%
topic = input("Enter the topic: ")

platform = input("Choose platform (LinkedIn/Instagram/X): ")

tone = input("Choose tone (Professional/Friendly/Funny): ")

audience = input("Target audience: ")

content_type = input("Content type (Post/Caption/Carousel): ")
# Out:
# Enter the topic: quantum computing:our future
# Choose platform (LinkedIn/Instagram/X): linkedin
# Choose tone (Professional/Friendly/Funny): professional
# Target audience: tech students
# Content type (Post/Caption/Carousel): post

# %% [markdown]
# ## Step 4: Create the AI Prompt
#
# This is the most important step.
#
# Here, we'll combine all the user inputs into a well-structured prompt.
#
# The better the prompt, the better the AI-generated content.

# %%
prompt = f"""
You are an expert Social Media Content Creator.

Generate high-quality content based on the following details.

Topic: {topic}
Platform: {platform}
Tone: {tone}
Target Audience: {audience}
Content Type: {content_type}

Return the output in the following format only:

## 📢 Social Media Post
(Write one engaging post)

## 🏷️ Hashtags
(Generate exactly 5 trending hashtags)

## 📣 Call-To-Action
(Write one engaging CTA)

## 💡 Next Content Idea
(Suggest one related content idea)

Keep the language engaging, concise, and platform-specific.
"""

# %% [markdown]
# ## Step 5: Generate Content using Google Gemini
#
# Now that our prompt is ready, we'll send it to the Gemini AI model.
#
# The model will understand our instructions and generate high-quality social media content based on the user's inputs.

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

# %% [markdown]
# ## Step 6: Display the Generated Content
#
# Let's display the AI-generated social media content.

# %%
print(response.text)
# Out:
# ## 📢 Social Media Post
# The code you are writing today runs on bits (0s and 1s). The code that will power tomorrow runs on **qubits**. ⚛️
#
# Quantum computing is no longer just a theoretical physics concept—it is the next major leap in technology. While classical supercomputers would take thousands of years to model complex molecular structures, optimize global logistics, or crack traditional encryption, a quantum computer can do it in minutes.
#
# For tech students, this represents one of the largest career opportunities of our decade.
#
# Here is why you should start paying attention now:
#
# 🔹 **The Quantum Talent Gap:** Tech giants like IBM, Google, and Microsoft, alongside hundreds of startups, are actively seeking developers who understand quantum logic. The supply of talent is low, but the demand is skyrocketing.
# ...

# %% [markdown]
# ## Step 7: Improve the Content
#
# One of the biggest advantages of Generative AI is that we don't have to start from scratch.
#
# We can ask the AI to improve, rewrite, shorten, or change the tone of previously generated content simply by giving it another prompt.

# %%
improvement_prompt = f"""
Rewrite the following social media content.

Content:

{response.text}

Make it:

- More engaging
- More professional
- More concise
- Add relevant emojis
- Keep it suitable for {platform}
"""

improved_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=improvement_prompt
)

print(improved_response.text)
# Out:
# Here's a rewritten version of your social media content, optimized for engagement, professionalism, conciseness, and suitability for LinkedIn:
#
# ---
#
# ## 🚀 The Qubit Revolution: Why Tech Students Should Act Now
#
# Your code today runs on bits. The code that will define tomorrow's breakthroughs runs on **qubits**. ⚛️ Quantum computing is no longer a distant theory; it's rapidly becoming a tangible force, poised to solve problems that are intractable for even the most powerful classical supercomputers—from accelerating drug discovery to optimizing global supply chains and securing critical data.
#
# For ambitious tech students, this isn't just fascinating science; it represents one of the most significant career opportunities of our generation. Here’s why you need to start exploring quantum computing today:
#
# ...

# %% [markdown]
# ## Step 9: Generate an AI Image Prompt
#
# Great content deserves great visuals!
#
# Let's ask AI to generate a professional image prompt that can be used in AI image generation tools to create social media graphics.

# %%
image_prompt = f"""
You are an expert AI Image Prompt Engineer.

Generate one highly detailed image prompt for the following topic.

Topic: {topic}

Target Audience: {audience}

The image should look professional, modern, attractive, and suitable for posting on {platform}.

Only generate the image prompt.
"""

image_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=image_prompt
)

print(image_response.text)
# Out:
# A breathtaking, ultra-modern, and hyper-realistic concept art render depicting the immense potential of quantum computing. The central focus is a sleek, highly polished quantum processor core – imagine a futuristic, minimalist dilution refrigerator bell or a sophisticated quantum chip array, crafted from brushed titanium and dark carbon fiber, with subtle glowing accents.
#
# From its intricate core, vibrant, crystalline light pathways and interconnected energy streams, representing entangled qubits, emanate outwards. These luminous elements glow in electric blues, neon purples, and radiant emerald greens, subtly twisting and merging to symbolize superposition and entanglement. These light trails are volumetric and dynamic, creating a sense of powerful, unseen activity.
#
# ...

# %%
from PIL import Image

# Updated the filename to match the actual file in /content/sample_data/
image = Image.open("/content/sample_data/Generated image 1 (3).png")

# %% [markdown]
# ## Step 12: Analyze the Generated Image using Gemini
#
# Generative AI is not limited to text generation.
#
# Gemini is a multimodal AI model, which means it can understand both text and images.
#
# Let's upload our generated image and ask Gemini to analyze whether it matches the social media content we created.

# %%
analysis_prompt = f"""
You are an expert social media marketing consultant.

Analyze this image based on the following details.

Topic: {topic}

Platform: {platform}

Target Audience: {audience}

Please answer:

1. Does this image match the topic?
2. Is it suitable for {platform}?
3. What emotions does it convey?
4. What could be improved?
5. Give the image a rating out of 10.
"""

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=[
        analysis_prompt,
        image
    ]
)

print(response.text)
# Out:
# Here is a professional social media marketing analysis of the image tailored to your campaign details.
#
# ---
#
# ### **1. Does this image match the topic?**
# **Yes, perfectly.**
# The visual centers on a stylized quantum chandelier (dilution refrigerator), which is the most recognizable icon of quantum hardware today. The holographic side panels feature genuine quantum physics concepts—such as the Bloch sphere representation, Dirac bra-ket notation ($\vert \psi \rangle$), network graphs for "Entanglement," and a map highlighting "Global Impact." It directly aligns with the idea of quantum computing driving the future.
#
# ---
#
# ### **2. Is it suitable for LinkedIn?**
# **Yes, highly suitable.**
# * **Professional & Modern Aesthetic:** High-resolution 3D/AI visuals with sleek dark modes perform exceptionally well on LinkedIn, particularly within tech, engineering, and data science communities.
# ...

# %%
from IPython.display import Markdown, display

display(Markdown(improved_response.text))
display(image)
# Out:
# Here's a rewritten version of your social media content, optimized for engagement, professionalism, conciseness, and suitability for LinkedIn:
#
# ---
#
# ## 🚀 The Qubit Revolution: Why Tech Students Should Act Now
#
# Your code today runs on bits. The code that will define tomorrow's breakthroughs runs on **qubits**. ⚛️ Quantum computing is no longer a distant theory; it's rapidly becoming a tangible force, poised to solve problems that are intractable for even the most powerful classical supercomputers—from accelerating drug discovery to optimizing global supply chains and securing critical data.
#
# For ambitious tech students, this isn't just fascinating science; it represents one of the most significant career opportunities of our generation. Here’s why you need to start exploring quantum computing today:
#
# ...
